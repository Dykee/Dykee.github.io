# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import ipywidgets
import os

# %%
# %matplotlib inline

# %%
climate = pd.read_csv("/home/dgorrell/Downloads/GlobalLandTemperatures_GlobalLandTemperaturesByMajorCity.csv")
agriculture = pd.read_excel (r'/home/dgorrell/Documents/independentStudy/Data/agricultureProductionByYearAndCountry.xlsx', sheet_name='OUTPUT')
foodDesert = pd.read_excel (r'/home/dgorrell/Documents/independentStudy/Data/atlasFoodDesertData2015 (1).xlsx', sheet_name='Food Access Research Atlas')

# %%
climate
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %%
agriculturetureturetureturetureturetureltureulturecultureiculturericulture
# Out:
#        Gross Agricultural Production Unnamed: 1 Unnamed: 2  \
# 0    (Constant 2004-2006 Int'l$1000)        NaN        NaN
# 1                              Order      FAO N   WDI Code
# 2                                  1        202        ZAF
# 3                                  2         32        CMR
# 4                                  3         37        CAF
# ..                               ...        ...        ...
# 186                              185        185        RUS
# 187                              186        230        UKR
# 188                              187        228        SVU
# 189                              188        NaN        NaN
# 190                              189       5000        WLD
#
#                    Unnamed: 3          Unnamed: 4         Unnamed: 5  \
# 0                         NaN                 NaN                NaN
# 1                     Country              Region         Sub-Region
# ...

# %%
foodDesert
# Out:
#        CensusTract    State    County  Urban  POP2010  OHU2010  \
# 0       1001020100  Alabama   Autauga      1     1912      693
# 1       1001020200  Alabama   Autauga      1     2170      743
# 2       1001020300  Alabama   Autauga      1     3373     1256
# 3       1001020400  Alabama   Autauga      1     4386     1722
# 4       1001020500  Alabama   Autauga      1    10766     4082
# ...            ...      ...       ...    ...      ...      ...
# 72859  56043000200  Wyoming  Washakie      0     3326     1317
# 72860  56043000301  Wyoming  Washakie      1     2665     1154
# 72861  56043000302  Wyoming  Washakie      1     2542     1021
# 72862  56045951100  Wyoming    Weston      0     3314     1322
# 72863  56045951300  Wyoming    Weston      1     3894     1699
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                      0         0  0.000000                  0  ...
# ...

# %%
# the
